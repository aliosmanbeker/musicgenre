# %%
import pandas as pd ; import numpy as np;import seaborn as sns ; import missingno as msno

# %%
dataset = pd.read_excel("music_genre.xlsx")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   instance_id       50000 non-null  float64
#  1   artist_name       50000 non-null  object
#  2   track_name        50000 non-null  object
#  3   popularity        49940 non-null  float64
#  4   acousticness      49940 non-null  float64
#  5   danceability      49940 non-null  float64
#  6   duration_ms       49940 non-null  float64
#  7   energy            49940 non-null  float64
#  8   instrumentalness  49940 non-null  float64
#  9   key               49940 non-null  object
#  10  liveness          49940 non-null  float64
#  11  loudness          49940 non-null  object
#  12  mode              49940 non-null  object
#  13  speechiness       49940 non-null  float64
#  14  tempo             49940 non-null  object
#  15  obtained_date     49940 non-null  object
# ...

# %%
dataset.isnull().sum()
# Out:
# instance_id          0
# artist_name          0
# track_name           0
# popularity          60
# acousticness        60
# danceability        60
# duration_ms         60
# energy              60
# instrumentalness    60
# key                 60
# liveness            60
# loudness            60
# mode                60
# speechiness         60
# tempo               60
# obtained_date       60
# valence             60
# music_genre         60
# dtype: int64

# %%
dataset[dataset.isnull().any(axis=1)]
# Out:
#        instance_id                artist_name  \
# 4424       42432.0                  New Order
# 7516       25176.0                       Mili
# 10027      57190.0               Kenny Dorham
# 10289      26917.0            Bill Evans Trio
# 10497      47919.0     Emerson, Lake & Palmer
# 10822      27075.0             Robert Glasper
# 10889      33048.0            Bill Evans Trio
# 13977      58225.0                        Yes
# 19994      49831.0                  New Order
# 30260      37160.0                Irma Thomas
# 30448      72113.0               Eric Clapton
# 30561      60897.0               Eric Clapton
# 30711      79968.0               Eric Clapton
# 31001      34085.0               Otis Redding
# 31025      49163.0               Otis Redding
# 31279      47648.0                Jessie Hill
# 31460      64318.0               Eric Clapton
# 31478      38810.0               Eric Clapton
# 31702      87966.0        Grand Funk Railroad
# ...

# %%
dataset = dataset.dropna()

# %%
dataset.isnull().sum()
# Out:
# instance_id         0
# artist_name         0
# track_name          0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# obtained_date       0
# valence             0
# music_genre         0
# dtype: int64

# %%
dataset = pd.read_excel("music_genre.xlsx")

dataset.replace('?', np.NaN)
dataset.isnull().sum()
# Out:
# instance_id          0
# artist_name          0
# track_name           0
# popularity          60
# acousticness        60
# danceability        60
# duration_ms         60
# energy              60
# instrumentalness    60
# key                 60
# liveness            60
# loudness            60
# mode                60
# speechiness         60
# tempo               60
# obtained_date       60
# valence             60
# music_genre         60
# dtype: int64
